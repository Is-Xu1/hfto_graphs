# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data9 = pd.read_csv('UofU 712-VS08-011_BHA 9_Accel-RPM - output data.csv', skiprows=35)
data10 = pd.read_csv('UofU 712-VS08-011_BHA 10_Accel-RPM - output data.csv', skiprows=35)
data14 = pd.read_csv('UofU 712-VS08-011_BHA 14 - output data.csv', skiprows=35)
data18 = pd.read_csv('UofU 650-05-376 BHA 18 - output data.csv', skiprows=35)
data21 = pd.read_csv('UofU 650-05-218 BHA 21 - output data.csv', skiprows=35)
data22 = pd.read_csv('UofU 650-05-218 BHA 22 - output data.csv', skiprows=35)
data23 = pd.read_csv('DATAMwEDR_UofU 650-05-211 BHA 23 - output data.csv', skiprows=35)
data30 = pd.read_csv('UofU 650-05-438 BHA 30 - output data.csv', skiprows=35)
data34 = pd.read_csv('BHA 34 650-05-551 - output data.csv', skiprows=35)
data35r1 = pd.read_csv('BHA 35r1 650-05-551 - output data.csv', skiprows=35)
data35r2 = pd.read_csv('BHA 35r2 650-05-551 - output data.csv', skiprows=35)
data38 = pd.read_csv('UofU 650-05-546 BHA 38 - output data.csv', skiprows=35)
data39 = pd.read_csv('UofU 650-05-546 BHA 39 - output data.csv', skiprows=35)
data42 = pd.read_csv('BHA 42 650-05-413 - output data.csv', skiprows=35)
listData = [data9,data10,data14,data18,data21,data22,data23,data30,data34,data35r1,\
            data35r2,data38,data39,data42]
shockList = pd.DataFrame([])
"Bit Box_ShYpeak(g)"
# Out:
# 'Bit Box_ShYpeak(g)'

# %%
shockList = pd.DataFrame({
    "Bit Box_ShYpeak(g)": [
        listData[x]["Bit Box_ShYpeak(g)"] for x in range(14)
    ]
})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Isaac Xu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bit Box_ShYpeak(g)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 3
#       1 shockList = pd.DataFrame({
#       2     "Bit Box_ShYpeak(g)": [
# ----> 3         listData[x]["Bit Box_ShYpeak(g)"] for x in range(14)
#       4     ]
#       5 })
#
# File c:\Users\Isaac Xu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File c:\Users\Isaac Xu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Bit Box_ShYpeak(g)'
