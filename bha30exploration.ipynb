# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv("UofU 650-05-438 BHA 30 - output data.csv", skiprows=35)

# %%
plt.hist(data1["Bit Box_ShYpeak(g)"])
# Out:
# (array([6.2434e+04, 2.1428e+04, 9.7800e+02, 9.4000e+01, 4.0000e+01,
#         1.7800e+02, 1.8700e+02, 3.1400e+02, 1.8200e+02, 6.9000e+01]),
#  array([  1.08219088,  26.09140467,  51.10061847,  76.10983226,
#         101.11904605, 126.12825984, 151.13747363, 176.14668742,
#         201.15590122, 226.16511501, 251.1743288 ]),
#  <BarContainer object of 10 artists>)

# %%
peak = data1[data1["Bit Box_ShYpeak(g)"] > 100]
len(peak)
# Out:
# 973
